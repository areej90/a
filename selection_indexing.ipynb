# %% [markdown]
# <a href="https://colab.research.google.com/github/areej90/a/blob/main/selection_indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction
# This notebook demonstrates various selection and indexing techniques in pandas to handle data efficiently. We use a traffic dataset for this example.

# %% [markdown]
# ### Importing Libraries
# Here, we import pandas, a powerful library for data manipulation and analysis.

# %%
import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# ### Loading Data
# We load the data from a CSV file into a pandas DataFrame. A DataFrame is a 2-dimensional labeled data structure.

# %%
df = pd.read_csv("Traffic.csv")

# %% [markdown]
# ### Viewing Data
# Using the `head()` function, we can view the first few rows of our DataFrame to understand its structure and the data it contains.

# %%
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %%
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %% [markdown]
# ### Accessing Column Data
# To access data from a single column, you use the column's label.

# %%
df.columns
# Out:
# Index(['Time', 'Date', 'Day of the week', 'CarCount', 'BikeCount', 'BusCount',
#        'TruckCount', 'Total', 'Traffic Situation'],
#       dtype='object')

# %%
df['Day of the week']
# Out:
# 0        Tuesday
# 1        Tuesday
# 2        Tuesday
# 3        Tuesday
# 4        Tuesday
#           ...
# 5947    Thursday
# 5948    Thursday
# 5949    Thursday
# 5950    Thursday
# 5951    Thursday
# Name: Day of the week, Length: 5952, dtype: object

# %%
df['Day of the week']
# Out:
# 0        Tuesday
# 1        Tuesday
# 2        Tuesday
# 3        Tuesday
# 4        Tuesday
#           ...
# 5947    Thursday
# 5948    Thursday
# 5949    Thursday
# 5950    Thursday
# 5951    Thursday
# Name: Day of the week, Length: 5952, dtype: object

# %% [markdown]
# ### Selecting Multiple Columns
# You can select multiple columns from a DataFrame by passing a list of column names.

# %%
df[['Time','Date','Day of the week']]
# Out:
#              Time  Date Day of the week
# 0     12:00:00 AM    10         Tuesday
# 1     12:15:00 AM    10         Tuesday
# 2     12:30:00 AM    10         Tuesday
# 3     12:45:00 AM    10         Tuesday
# 4      1:00:00 AM    10         Tuesday
# ...           ...   ...             ...
# 5947  10:45:00 PM     9        Thursday
# 5948  11:00:00 PM     9        Thursday
# 5949  11:15:00 PM     9        Thursday
# 5950  11:30:00 PM     9        Thursday
# 5951  11:45:00 PM     9        Thursday
#
# [5952 rows x 3 columns]

# %%
df[['Time', 'Date','Day of the week']]
# Out:
#              Time  Date Day of the week
# 0     12:00:00 AM    10         Tuesday
# 1     12:15:00 AM    10         Tuesday
# 2     12:30:00 AM    10         Tuesday
# 3     12:45:00 AM    10         Tuesday
# 4      1:00:00 AM    10         Tuesday
# ...           ...   ...             ...
# 5947  10:45:00 PM     9        Thursday
# 5948  11:00:00 PM     9        Thursday
# 5949  11:15:00 PM     9        Thursday
# 5950  11:30:00 PM     9        Thursday
# 5951  11:45:00 PM     9        Thursday
#
# [5952 rows x 3 columns]

# %% [markdown]
# ### Using iloc for Index-Based Selection
# The `iloc` method is used for index-based selection, allowing us to select rows and columns by their integer index.

# %%
df.iloc[5]
# Out:
# Time                 1:15:00 AM
# Date                         10
# Day of the week         Tuesday
# CarCount                     15
# BikeCount                     1
# BusCount                      1
# TruckCount                   39
# Total                        56
# Traffic Situation        normal
# Name: 5, dtype: object

# %%
df.iloc[5:10]
# Out:
#          Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 5  1:15:00 AM    10         Tuesday        15          1         1
# 6  1:30:00 AM    10         Tuesday        14          2         2
# 7  1:45:00 AM    10         Tuesday        13          2         1
# 8  2:00:00 AM    10         Tuesday         7          0         0
# 9  2:15:00 AM    10         Tuesday        13          0         0
#
#    TruckCount  Total Traffic Situation
# 5          39     56            normal
# 6          27     45            normal
# 7          20     36            normal
# 8          26     33            normal
# 9          34     47            normal

# %% [markdown]
# ### Using loc for Label-Based Selection
# The `loc` method allows for label-based selection. This example demonstrates selecting data by multi-index labels.

# %%
df.loc[5:10,['Date','Time']]
# Out:
#     Date        Time
# 5     10  1:15:00 AM
# 6     10  1:30:00 AM
# 7     10  1:45:00 AM
# 8     10  2:00:00 AM
# 9     10  2:15:00 AM
# 10    10  2:30:00 AM

# %%
df.loc[5:10, ['Date', 'Time']]
# Out:
#     Date        Time
# 5     10  1:15:00 AM
# 6     10  1:30:00 AM
# 7     10  1:45:00 AM
# 8     10  2:00:00 AM
# 9     10  2:15:00 AM
# 10    10  2:30:00 AM

# %%
df = df.set_index([ 'Time','Day of the week'])
df.loc[('12:00:00 AM', 'Monday')]
# Out:
# <ipython-input-17-1cbde8cf5427>:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[('12:00:00 AM', 'Monday')]
#                              Date  CarCount  BikeCount  BusCount  TruckCount  \
# Time        Day of the week
# 12:00:00 AM Monday             16        11          2         2          39
#             Monday             23        15          1         0          37
#             Monday             30        14          2         0          33
#             Monday              6         9          2         0          27
#             Monday             16        18          4         1          28
#             Monday             23        13          2         1          17
#             Monday             30        13          3         1          12
#             Monday              6        11          3         0          26
#
#                              Total Traffic Situation
# Time        Day of the week
# 12:00:00 AM Monday              54            normal
#             Monday              53            normal
#             Monday              49            normal
#             Monday              38            normal
#             Monday              51            normal
#             Monday              33               low
#             Monday              29               low
#             Monday              40            normal

# %% [markdown]
# ### Resetting Index
# Resetting the index of a DataFrame can simplify data handling, especially after operations that may create a hierarchical index.

# %%
df = df.reset_index()
df
# Out:
#              Time Day of the week  Date  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM         Tuesday    10        13          2         2
# 1     12:15:00 AM         Tuesday    10        14          1         1
# 2     12:30:00 AM         Tuesday    10        10          2         2
# 3     12:45:00 AM         Tuesday    10        10          2         2
# 4      1:00:00 AM         Tuesday    10        11          2         1
# ...           ...             ...   ...       ...        ...       ...
# 5947  10:45:00 PM        Thursday     9        16          3         1
# 5948  11:00:00 PM        Thursday     9        11          0         1
# 5949  11:15:00 PM        Thursday     9        15          4         1
# 5950  11:30:00 PM        Thursday     9        16          5         0
# 5951  11:45:00 PM        Thursday     9        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0             24     41            normal
# 1             36     52            normal
# 2             32     46            normal
# 3             36     50            normal
# 4             34     48            normal
# ...          ...    ...               ...
# 5947          36     56            normal
# 5948          30     42            normal
# 5949          25     45            normal
# 5950          27     48            normal
# 5951          15     33               low
#
# [5952 rows x 9 columns]

# %% [markdown]
# ### Conditional Selection Using loc
# We can perform conditional selection using `loc` to select rows based on a specific condition.

# %%
df[df['Total'] > 250]
# Out:
#              Time Day of the week  Date  CarCount  BikeCount  BusCount  \
# 3303   9:45:00 AM          Friday    13       171         59        27
# 3307  10:45:00 AM          Friday    13       178         68        28
# 3308  11:00:00 AM          Friday    13       169         70        20
# 3311  11:45:00 AM          Friday    13       179         46        27
# 3315  12:45:00 PM          Friday    13       174         67        30
# 3318   1:30:00 PM          Friday    13       175         63        19
# 3319   1:45:00 PM          Friday    13       172         62        20
# 3321   2:15:00 PM          Friday    13       172         65        18
# 3974   9:30:00 AM          Friday    20       170         62        18
# 3976  10:00:00 AM          Friday    20       166         63        22
# 3986  12:30:00 PM          Friday    20       173         63        13
# 3991   1:45:00 PM          Friday    20       168         59        24
# 3993   2:15:00 PM          Friday    20       179         63        12
# 4646   9:30:00 AM          Friday    27       180         69        29
# 4648  10:00:00 AM          Friday    27       167         60        27
# 4650  10:30:00 AM          Friday    27       180         62        26
# 5319   9:45:00 AM          Friday     3       168         68        27
# 5333   1:15:00 PM          Friday     3       174         54        25
# 5340   3:00:00 PM          Friday     3       179         60        12
#
#       TruckCount  Total Traffic Situation
# 3303           3    260             heavy
# 3307           4    278             heavy
# 3308           3    262             heavy
# 3311           3    255             heavy
# 3315           1    272             heavy
# 3318           3    260             heavy
# 3319           2    256             heavy
# 3321           2    257             heavy
# 3974           2    252             heavy
# 3976           1    252             heavy
# 3986           2    251             heavy
# 3991           1    252             heavy
# 3993           2    256             heavy
# 4646           1    279             heavy
# 4648           3    257             heavy
# 4650           4    272             heavy
# 5319           2    265             heavy
# 5333           1    254             heavy
# 5340           0    251             heavy

# %%
df[df['Total'] > 250]
# Out:
#              Time Day of the week  Date  CarCount  BikeCount  BusCount  \
# 3303   9:45:00 AM          Friday    13       171         59        27
# 3307  10:45:00 AM          Friday    13       178         68        28
# 3308  11:00:00 AM          Friday    13       169         70        20
# 3311  11:45:00 AM          Friday    13       179         46        27
# 3315  12:45:00 PM          Friday    13       174         67        30
# 3318   1:30:00 PM          Friday    13       175         63        19
# 3319   1:45:00 PM          Friday    13       172         62        20
# 3321   2:15:00 PM          Friday    13       172         65        18
# 3974   9:30:00 AM          Friday    20       170         62        18
# 3976  10:00:00 AM          Friday    20       166         63        22
# 3986  12:30:00 PM          Friday    20       173         63        13
# 3991   1:45:00 PM          Friday    20       168         59        24
# 3993   2:15:00 PM          Friday    20       179         63        12
# 4646   9:30:00 AM          Friday    27       180         69        29
# 4648  10:00:00 AM          Friday    27       167         60        27
# 4650  10:30:00 AM          Friday    27       180         62        26
# 5319   9:45:00 AM          Friday     3       168         68        27
# 5333   1:15:00 PM          Friday     3       174         54        25
# 5340   3:00:00 PM          Friday     3       179         60        12
#
#       TruckCount  Total Traffic Situation
# 3303           3    260             heavy
# 3307           4    278             heavy
# 3308           3    262             heavy
# 3311           3    255             heavy
# 3315           1    272             heavy
# 3318           3    260             heavy
# 3319           2    256             heavy
# 3321           2    257             heavy
# 3974           2    252             heavy
# 3976           1    252             heavy
# 3986           2    251             heavy
# 3991           1    252             heavy
# 3993           2    256             heavy
# 4646           1    279             heavy
# 4648           3    257             heavy
# 4650           4    272             heavy
# 5319           2    265             heavy
# 5333           1    254             heavy
# 5340           0    251             heavy

# %% [markdown]
# ### Conditional Selection Using query
# The `query` method allows for filtering data using a condition, similar to the conditional selection but often more readable and concise.

# %%
df.query('Total > 250')
# Out:
#              Time Day of the week  Date  CarCount  BikeCount  BusCount  \
# 3303   9:45:00 AM          Friday    13       171         59        27
# 3307  10:45:00 AM          Friday    13       178         68        28
# 3308  11:00:00 AM          Friday    13       169         70        20
# 3311  11:45:00 AM          Friday    13       179         46        27
# 3315  12:45:00 PM          Friday    13       174         67        30
# 3318   1:30:00 PM          Friday    13       175         63        19
# 3319   1:45:00 PM          Friday    13       172         62        20
# 3321   2:15:00 PM          Friday    13       172         65        18
# 3974   9:30:00 AM          Friday    20       170         62        18
# 3976  10:00:00 AM          Friday    20       166         63        22
# 3986  12:30:00 PM          Friday    20       173         63        13
# 3991   1:45:00 PM          Friday    20       168         59        24
# 3993   2:15:00 PM          Friday    20       179         63        12
# 4646   9:30:00 AM          Friday    27       180         69        29
# 4648  10:00:00 AM          Friday    27       167         60        27
# 4650  10:30:00 AM          Friday    27       180         62        26
# 5319   9:45:00 AM          Friday     3       168         68        27
# 5333   1:15:00 PM          Friday     3       174         54        25
# 5340   3:00:00 PM          Friday     3       179         60        12
#
#       TruckCount  Total Traffic Situation
# 3303           3    260             heavy
# 3307           4    278             heavy
# 3308           3    262             heavy
# 3311           3    255             heavy
# 3315           1    272             heavy
# 3318           3    260             heavy
# 3319           2    256             heavy
# 3321           2    257             heavy
# 3974           2    252             heavy
# 3976           1    252             heavy
# 3986           2    251             heavy
# 3991           1    252             heavy
# 3993           2    256             heavy
# 4646           1    279             heavy
# 4648           3    257             heavy
# 4650           4    272             heavy
# 5319           2    265             heavy
# 5333           1    254             heavy
# 5340           0    251             heavy
